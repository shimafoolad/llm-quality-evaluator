# %% [markdown]
# # Evaluation

# %%
curl -X 'POST' \
    'http://localhost:8000/evaluate/' \
    -H 'Content-Type: application/json' \
    -d '{"dataset_name":"DB_20250319_125231", "num_samples": 1 }'

# %% [markdown]
# # Create Dataset

# %%
curl -X 'POST' \
  'http://localhost:8000/datasets/' \
  -H 'accept: application/json' \
  -H 'Content-Type: multipart/form-data' \
  -F 'directory_path=data/convo_files'

# %%
curl -X POST "http://localhost:8000/datasets/" \
  -F "files=@/path/to/conversation1.csv" \
  -F "files=@/path/to/conversation2.csv"

# %% [markdown]
# # Add Conversation to Dataset

# %%
curl -X 'POST' \
  'http://localhost:8000/datasets/conversations/' \
  -H 'accept: application/json' \
  -H 'Content-Type: multipart/form-data' \
  -F 'dataset_name=	db_autotest' \
  -F 'file_path=data/json_files/bot_first/conv_1.json'

# %% [markdown]
# # Check Task Status:

# %%
curl -X GET "http://localhost:8000/tasks/cc2443fe-fafb-4388-b928-c0de1250e163"

# %% [markdown]
# # List All Tasks:

# %%
curl -X GET "http://localhost:8000/tasks/"
